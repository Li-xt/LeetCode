# %% [markdown]
# Solution_1 :

# %%
class Solution(object):
    def isValidSudoku(self, board):
        """
        :type board: List[List[str]]
        :rtype: bool
        """
        #列判断
        i = 0
        while i < 9:
            j = 0
            d = {}
            while j < 9:
                if board[i][j] != '.' and board[i][j] in d:
                    return False
                else:
                    d[board[i][j]] = True
                j += 1
            i += 1
        #行判断
        j = 0
        while j < 9:
            i = 0
            d = {}
            while i < 9:
                if board[i][j] != '.' and board[i][j] in d:
                    return False
                else:
                    d[board[i][j]] = True
                i += 1
            j += 1
        #九宫格
        i = 0
        while i < 9:
            j = 0
            while j < 9:
                m = 0;d = {}
                while m < 3:
                    n = 0
                    while n < 3:
                        if board[i + m][j + n] != '.' and board[i + m][j + n] in d:
                            return False
                        else:
                            d[board[i + m][j + n]] = True
                        n += 1
                    m += 1
                j += 3
            i += 3
        return True

# %% [markdown]
# Solution_2 :

# %%
class Solution:
    def isValidSudoku(self, board: List[List[str]]) -> bool:
        row = list()
        col = list()
        box = list()
        f = 0
        
        for i in range(9):
            col.clear()
            row.clear()
            for j in range(9):
                if board[i][j] == '.':
                    continue
                if board[i][j] in col:
                    return False
                col.append(board[i][j])
            
            for j in range(9):
                if board[j][i] == '.':
                    continue
                if board[j][i] in row:
                    return False
                row.append(board[j][i])
            
        rs = 0
        re = 2
        
        while re <= 8:
            cs = 0
            ce = 2
            while ce <= 8:
                box.clear()
                for i in range(rs, re+1):
                    for j in range(cs, ce+1):
                        if board[i][j] == '.':
                            continue
                        if board[i][j] in box:
                            return False
                        box.append(board[i][j])
                cs = cs + 3
                ce = ce + 3
            rs = rs + 3
            re = re + 3
        
        return True

# %% [markdown]
# Solution_3 :

# %%
class Solution:
    def isValidSudoku(self, board: List[List[str]]) -> bool:
        # Validate rows
        for row in board:
            reduced_row = [x for x in row if x != '.']
            if len(set(reduced_row)) != len(reduced_row):
                return False
        # Validate cols
        for col_index in range(len(board)):
            dup_set = set()
            for row in board:
                if row[col_index] == '.':
                    continue
                if row[col_index] in dup_set:
                    return False
                else:
                    dup_set.add(row[col_index])
        # Validate 3x3
        for x in range(0,7,3):
            for y in range(0,7,3):
                dup_set = set()
                for x_box in range(x,x+3):
                    for y_box in range(y,y+3):
                        if board[y_box][x_box] == '.':
                            continue
                        if board[y_box][x_box] in dup_set:
                            return False
                        else:
                            dup_set.add(board[y_box][x_box])
        return True
